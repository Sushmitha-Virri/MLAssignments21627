# %% [markdown]
# 1. Numpy:
#
# a. Using NumPy create random vector of size 15 having only Integers in the range 1-20.
# 1. Reshape the array to 3 by 5
# 2. Print array shape.
# 3. Replace the max in each row by 0
#
# Create a 2-dimensional array of size 4 x 3 (composed of 4-byte integer elements), also print the shape, type and data type
# of the array

# %%
import numpy as np
# creating a random vector of size 15 having integers in the range 1-20
int_arr = np.random.randint(1, 21, 15)

# reshaping the array to 3 by 5 with the help of reshape() function
int_arr = int_arr.reshape(3, 5)

#to print the array
int_arr
# Out:
# array([[ 1,  8, 13,  2, 19],
#        [ 5,  3,  7, 12,  9],
#        [ 1, 14, 15, 16,  2]])

# %%
# print array shape
print("Shape of the array:", int_arr.shape)
# Out:
# Shape of the array: (3, 5)

# %%
#Replacing the max in each row by 0
int_arr[np.where(int_arr==np.max(int_arr))] = 0

#to print the array after replacing
int_arr
# Out:
# array([[ 1,  8, 13,  2,  0],
#        [ 5,  3,  7, 12,  9],
#        [ 1, 14, 15, 16,  2]])

# %%
# to create a 2-dimensional array of size 4 x 3 (composed of 4-byte integer elements)
array1 = np.array([[10, 20, 22], [20, 42, 61], [1, 0, 9], [12, 8, 53]], dtype = np.int32)

# to print the shape,type and data type of the array
print("Shape of the array:", array1.shape)
print("Type of the array:", type(array1))
print("Data type of the array:", array1.dtype)
# Out:
# Shape of the array: (4, 3)
# Type of the array: <class 'numpy.ndarray'>
# Data type of the array: int32

# %% [markdown]
# b. Write a program to compute the eigenvalues and right eigenvectors of a given square array given below:
#
# [[ 3 -2]
#
# [ 1 0]]

# %%
import numpy as np
#to define the square array using array() function of the numpy libraray
array2 = np.array([[3, -2], [1, 0]])
#to calculate the eigenvalues and right eigenvectors of the given square array using linalg.eig() function
eigen_values, eigen_vectors = np.linalg.eig(array2)

#to print the computed values
print("eigenvalues of the square array : ", eigen_values)
print("eigenvectors of the square array : ", eigen_vectors)
# Out:
# eigenvalues of the square array :  [2. 1.]
# eigenvectors of the square array :  [[0.89442719 0.70710678]
#  [0.4472136  0.70710678]]

# %% [markdown]
# c. Compute the sum of the diagonal element of a given array.
#
# [[0 1 2]
#
# [3 4 5]]

# %%
import numpy as np
array3 = np.array([[0, 1, 2], [3, 4, 5]])

#to compute the sum of diagonal elements using trace() function
diag_elements_sum = np.trace(array3)

# to print the sum of the diagonal elements
print("sum of the diagonal elements of given array : ", diag_elements_sum)
# Out:
# sum of the diagonal elements of given array :  4

# %% [markdown]
# 2. Matplotlib
#
#   Write a Python programming to create a below chart of the popularity of programming Languages.
#
#   Sample data:
#
#  Programming languages: Java, Python, PHP, JavaScript, C#, C++
#
#    Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
import matplotlib.pyplot as plt
# defining the programming languages as a list
prg_lang = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']

#defining their popularity
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]

#using plt.pie() function to create a pie chart 
#input data is the popularity list and labels is the prog_lang list
plt.pie(popularity, labels=prg_lang, autopct = '%1.1f%%', wedgeprops = {'edgecolor' : "black"})

#to show the plot
plt.show()
